# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

tweets_data_path = 'data/twitter_data.txt'

tweets_data = []
tweets_file = open(tweets_data_path, "r")
count=0
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue


# print(tweets_data[1]['user']['name'])
# print(tweets_data[1]['user']['location'])
# print(tweets_data[1]['user']['description'])
# print(tweets_data[1]['text'])
print(tweet)
# Out:
# {'is_quote_status': False, 'in_reply_to_status_id': None, 'favorite_count': 0, 'extended_entities': {'media': [{'media_url_https': 'https://pbs.twimg.com/media/C7TWtmoX0AATsjr.jpg', 'sizes': {'medium': {'resize': 'fit', 'w': 640, 'h': 640}, 'large': {'resize': 'fit', 'w': 640, 'h': 640}, 'small': {'resize': 'fit', 'w': 640, 'h': 640}, 'thumb': {'resize': 'crop', 'w': 150, 'h': 150}}, 'indices': [110, 133], 'type': 'photo', 'media_url': 'http://pbs.twimg.com/media/C7TWtmoX0AATsjr.jpg', 'id': 843535109177462784, 'source_user_id': 4032111567, 'source_status_id': 843535119730294784, 'id_str': '843535109177462784', 'expanded_url': 'https://twitter.com/OfficialBullion/status/843535119730294784/photo/1', 'source_status_id_str': '843535119730294784', 'display_url': 'pic.twitter.com/niThVGVdk6', 'url': 'https://t.co/niThVGVdk6', 'source_user_id_str': '4032111567'}]}, 'retweeted': False, 'user': {'name': 'ROB KING', 'geo_enabled': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_bann
# ...

# %%
tweets_df = pd.DataFrame(columns=('name','location','description','tweet'))
for i in range(len(tweets_data)):
    tweets_df.loc[i] = [tweets_data[i]['user']['name'], tweets_data[i]['user']['location'], tweets_data[i]['user']['description'], tweets_data[i]['text']]
    
tweets_df.head(50)
# Out:
#                     name                        location  \
# 0    Hovikirjeenvaihtaja                         Finland
# 1   Pak Media Revolution   Pakistan | #BBM Pin: 2AC8376E
# 2                     晴香                            None
# 3            Kris Cooper                            None
# 4            Shawna B ❤️                    New York, NY
# 5                    🍫 ™                            None
# 6          The Golden Rx                 Los Angeles, CA
# 7             damilaara♀             london // leicester
# 8              autonoMIA                   Mutum, Brasil
# 9   Hiddleston Actor Fan                            None
# 10        mçsâūxė mïrãgę                  Greensboro, NC
# 11        SouthWalesJobs                  Swansea, Wales
# 12          Angie Silver                 London, England
# 13         Poonam Taneja                          London
# 14      Bagja M Suryaman              Bandung, Indonesia
# ...
