# %%
import twitter
import urllib.parse
from pprint import pprint as pp

class TwitterAPI(object):
    """
    TwitterAPI class allows the Connection to Twitter via OAuth
    once you have registered with Twitter and receive the 
    necessary credentiials 
    """


    def __init__(self): 
        consumer_key = 'bxZ2ypZgrxusqKvUGnlv1KNew'
        consumer_secret = 'HiAk5tuYc657MNKSb8odAxnU33fm4nLAAXY10PkhM3uUxbP9XB'
        access_token = '2983449373-pH31LSzmmrbgXrkZx08FWDnWqxNmWx74aMwLMt4'
        access_secret = 'Q41AgD2NdZ6n2UQWh8YM6nMosCKLENWrfqh1oiUNhp4R9'
     
        self.consumer_key = consumer_key
        self.consumer_secret = consumer_secret
        self.access_token = access_token
        self.access_secret = access_secret
        self.auth = twitter.oauth.OAuth(access_token, access_secret, consumer_key, consumer_secret)
        self.api = twitter.Twitter(auth=self.auth)

    def searchTwitter(self, q, max_res=10,**kwargs):
        search_results = self.api.search.tweets(q=q, count=10, **kwargs)
        statuses = search_results['statuses']
        max_results = min(1000, max_res)

        for _ in range(10): 
            try:
                next_results = search_results['search_metadata']['next_results']
            except KeyError as e: 
                break

            next_results = urllib.parse.parse_qsl(next_results[1:])
            kwargs = dict(next_results)
            search_results = self.api.search.tweets(**kwargs)
            statuses += search_results['statuses']

            if len(statuses) > max_results: 
                break
        return statuses

    def parseTweets(self, statuses):
        return [ (status['id'], 
                  status['created_at'], 
                  status['user']['id'],
                  status['user']['name'], 
                  status['text'], 
                  url['expanded_url']) 
                        for status in statuses 
                            for url in status['entities']['urls'] ]

# %%
t= TwitterAPI()
q="ApacheSpark"
tsearch = t.searchTwitter(q)
len(tsearch)
#tparse = t.parseTweets(tsearch)
#pp(tparse)
# Out:
# 20

# %%
import json

json.dumps(tsearch)
# Out:
# '[{"in_reply_to_user_id": null, "id_str": "856002595957096448", "contributors": null, "favorited": false, "coordinates": null, "is_quote_status": false, "favorite_count": 0, "retweet_count": 1, "retweeted": false, "truncated": false, "in_reply_to_status_id": null, "geo": null, "source": "<a href=\\"https://g3rv4.com\\" rel=\\"nofollow\\">StackOMentions</a>", "id": 856002595957096448, "in_reply_to_status_id_str": null, "user": {"profile_background_color": "F5F8FA", "id_str": "834601516958892033", "profile_link_color": "1DA1F2", "time_zone": "Pacific Time (US & Canada)", "id": 834601516958892033, "has_extended_profile": false, "statuses_count": 2938, "screen_name": "StackOMentions", "profile_sidebar_fill_color": "DDEEF6", "favourites_count": 0, "contributors_enabled": false, "follow_request_sent": false, "lang": "en", "followers_count": 30, "is_translator": false, "default_profile_image": true, "profile_background_tile": false, "url": "https://t.co/6igBhLCKYL", "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "geo_enabled": false, "listed_count": 4, "location": "", "name": "StackO Mentions", "default_profile": true, "is_translation_enabled": false, "description": "I\'m a bot that retweets whatever mentions @StackOverflow", "translator_type": "none", "utc_offset": -25200, "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "following": false, "protected": false, "profile_background_image_url": null, "created_at": "Thu Feb 23 03:11:22 +0000 2017", "entities": {"url": {"urls": [{"display_url": "github.com/g3rv4/retweeter", "expanded_url": "https://github.com/g3rv4/retweeter", "url": "https://t.co/6igBhLCKYL", "indices": [0, 23]}]}, "description": {"urls": []}}, "verified": false, "profile_background_image_url_https": null, "notifications": false, "profile_text_color": "333333", "profile_use_background_image": true, "profile_sidebar_border_color": "C0DEED", "friends_count": 0}, "place": null, "metadata": {"result_type": "recent", "iso_language_code": "en"}, "retweeted_status": {"in_reply_to_user_id": null, "id_str": "856002592995987456", "contributors": null, "favorited": false, "coordinates": null, "is_quote_status": false, "favorite_count": 0, "retweet_count": 1, "retweeted": false, "truncated": false, "in_reply_to_status_id": null, "geo": null, "source": "<a href=\\"http://twitter.com\\" rel=\\"nofollow\\">Twitter Web Client</a>", "id": 856002592995987456, "in_reply_to_status_id_str": null, "user": {"profile_background_color": "131516", "id_str": "68918913", "profile_link_color": "4A913C", "time_zone": "New Delhi", "id": 68918913, "has_extended_profile": true, "statuses_count": 92, "screen_name": "_mrsrinivas", "profile_sidebar_fill_color": "EFEFEF", "favourites_count": 22, "contributors_enabled": false, "follow_request_sent": false, "lang": "en", "followers_count": 113, "is_translator": false, "default_profile_image": false, "profile_background_tile": true, "url": "https://t.co/RoARPgm1CW", "profile_image_url_https": "https://pbs.twimg.com/profile_images/856003986566131712/2B0lwCXm_normal.jpg", "profile_sidebar_border_color": "EEEEEE", "geo_enabled": true, "listed_count": 2, "location": "Hyderabad", "name": "Srinivas", "default_profile": false, "is_translation_enabled": false, "description": "Proud Indian, #Cricket Lover, @SunRisers fan and #SoftwareEngineer by profession.", "translator_type": "none", "utc_offset": 19800, "profile_image_url": "http://pbs.twimg.com/profile_images/856003986566131712/2B0lwCXm_normal.jpg", "following": false, "protected": false, "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif", "created_at": "Wed Aug 26 06:53:40 +0000 2009", "entities": {"url": {"urls": [{"display_url": "mrsrinivas.github.io", "expanded_url": "https://mrsrinivas.github.io/", "url": "https://t.co/RoARPgm1CW", "indices": [0, 23]}]}, "description": {"urls": []}}, "verified": false, "profile_ba ...
