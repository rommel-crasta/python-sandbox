# %%
import json
import mimeparse
import requests
import urllib.parse
from pprint import pprint as pp

MEETUP_API_HOST = 'https://api.meetup.com'
EVENTS_URL = MEETUP_API_HOST + '/2/events.json'
MEMBERS_URL = MEETUP_API_HOST + '/2/members.json'
GROUPS_URL = MEETUP_API_HOST + '/2/groups.json'
RSVPS_URL = MEETUP_API_HOST + '/2/rsvps.json'
PHOTOS_URL = MEETUP_API_HOST + '/2/photos.json'
GROUP_URLNAME = 'London-Machine-Learning-Meetup'
# GROUP_URLNAME = 'London-Machine-Learning-Meetup' # 'Data-Science-London'

class MeetupAPI(object):
    """
    Retrieves information about meetup.com
    """
    def __init__(self, api_key, num_past_events=10, http_timeout=10,
                 http_retries=2):
        """
        Create a new instance of MeetupAPI
        """
        self._api_key = api_key
        self._http_timeout = http_timeout
        self._http_retries = http_retries
        self._num_past_events = num_past_events

    def get_past_events(self):
        """
        Get past meetup events for a given meetup group
        """
        params = {'key': self._api_key,
                  'group_urlname': GROUP_URLNAME,
                  'status': 'past',
                  'desc': 'true'}
        if self._num_past_events:
            params['page'] = str(self._num_past_events)

        query = urllib.parse.urlencode(params)
        url = '{0}?{1}'.format(EVENTS_URL, query)
        response = requests.get(url, timeout=self._http_timeout)
        data = response.json()['results']
        return data
    
    def get_members(self):
        """
        Get meetup members for a given meetup group
        """
        params = {'key': self._api_key,
                  'group_urlname': GROUP_URLNAME,
                  'offset': '0',
                  'format': 'json',
                  'page': '100',
                  'order': 'name'}
        query = urllib.parse.urlencode(params)
        url = '{0}?{1}'.format(MEMBERS_URL, query)
        response = requests.get(url, timeout=self._http_timeout)
        data = response.json()['results']
        return data
    
    def get_groups_by_member(self, member_id='38680722'):
        """
        Get meetup groups for a given meetup member
        """
        params = {'key': self._api_key,
                  'member_id': member_id,
                  'offset': '0',
                  'format': 'json',
                  'page': '100',
                  'order': 'id'}

        query = urllib.parse.urlencode(params)
        url = '{0}?{1}'.format(GROUPS_URL, query)
        response = requests.get(url, timeout=self._http_timeout)
        data = response.json()['results']
        return data

# %%
m = MeetupAPI(api_key='7a801912457770261765664e38132e2c')

# %%
members = m.get_members()
len(members)

events = m.get_past_events()
len(events)
# Out:
# 10

# %%
pp(members[10:15])
# Out:
# [{'city': 'London',
#   'country': 'gb',
#   'id': 45273322,
#   'joined': 1447690287000,
#   'lat': 51.46,
#   'link': 'http://www.meetup.com/members/45273322',
#   'lon': -0.21,
#   'name': 'Aaron Signorelli',
#   'other_services': {'facebook': {'identifier': 'https://www.facebook.com/app_scoped_user_id/36702559/'},
#                      'twitter': {'identifier': '@AaronSig'}},
#   'photo': {'base_url': 'https://secure.meetupstatic.com',
#             'photo_id': 50875612,
#             'photo_link': 'https://secure.meetupstatic.com/photos/member/d/9/3/c/member_50875612.jpeg',
#             'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/9/3/c/thumb_50875612.jpeg',
#             'type': 'member'},
#   'self': {'common': {}},
#   'state': '17',
#   'status': 'active',
#   'topics': [{'id': 659, 'name': 'Web Design', 'urlkey': 'webdesign'},
#              {'id': 3833,
#               'name': 'Software Development',
#               'urlkey': 'softwaredev'},
#              {'id': 10102,
#               'name': 'Internet Professionals',
#               'urlkey': 'internetpro'},
#              {'id': 10110, 'name': 'Interaction Design', 'urlkey': 'ixd'},
#              {'id': 10164, 'name': 'LAMP', 'urlkey': 'lampsoftware'},
#              {'id': 10209, 'name': 'Web Technology', 'urlkey': 'web'},
#              {'id': 15585,
#               'name': 'Online Marketing',
#               'urlkey': 'online-marketing'},
#              {'id': 19243,
#               'name': 'User Experience',
#               'urlkey': 'user-experience'},
#              {'id': 127567,
#               'name': 'iOS Development',
#               'urlkey': 'ios-development'},
#              {'id': 128595,
#               'name': 'Internet Startups',
#               'urlkey': 'internet-startups'},
#              {'id': 563, 'name': 'Open Source', 'urlkey': 'opensource'},
#              {'id': 10579, 'name': 'Technology', 'urlkey': 'technology'},
#              {'id': 15582,
#               'name': 'Web Development',
#               'urlkey': 'web-development'},
#              {'id': 19882,
#               'name': 'Entrepreneurship',
#               'urlkey': 'entrepreneurship'},
#              {'id': 29971,
#               'name': 'Machine Learning',
#               'urlkey': 'machine-learning'},
#              {'id': 48471,
#               'name': 'Computer programming',
#               'urlkey': 'computer-programming'},
#              {'id': 7029, 'name': 'JavaScript', 'urlkey': 'javascript'},
#              {'id': 9696, 'name': 'New Technology', 'urlkey': 'newtech'},
#              {'id': 21441,
#               'name': 'Mobile Development',
#               'urlkey': 'mobile-development'},
#              {'id': 21681,
#               'name': 'Startup Businesses',
#               'urlkey': 'startup-businesses'},
#              {'id': 78565, 'name': 'HTML5', 'urlkey': 'html5'},
#              {'id': 85951,
#               'name': 'JavaScript Frameworks',
#               'urlkey': 'javascript-frameworks'}],
#   'visited': 1476349292000},
#  {'city': 'Wellington',
#   'country': 'nz',
#   'id': 99137932,
#   'joined': 1491199012000,
#   'lat': -41.28,
#   'link': 'http://www.meetup.com/members/99137932',
#   'lon': 174.78,
#   'name': 'Aaron Yee',
#   'other_services': {},
#   'photo': {'base_url': 'https://secure.meetupstatic.com',
#             'photo_id': 127074312,
#             'photo_link': 'https://secure.meetupstatic.com/photos/member/d/4/2/8/member_127074312.jpeg',
#             'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/4/2/8/thumb_127074312.jpeg',
#             'type': 'member'},
#   'self': {'common': {}},
#   'status': 'active',
#   'topics': [{'id': 21681,
#               'name': 'Startup Businesses',
#               'urlkey': 'startup-businesses'},
#              {'id': 15121, 'name': 'Leadership', 'urlkey': 'leadership'},
#              {'id': 3880,
#               'name': 'Professional Development',
#               'urlkey': 'prodev'},
#              {'id': 3307, 'name': 'Toastmasters', 'urlkey': 'toastmasters'},
#              {'id': 9696, 'name': 'New Technology', 'urlkey': 'newtech'},
#              {'id': 38660, 'name': 'Lean Startup', 'urlkey': 'lean-startup'}],
#   'visited': 1491199012000},
#  {'city': 'London',
#   'country': 'gb',
#   'id': 191434382,
#   'joined': 1446426954000,
#   'lat': 51.58,
#   'link': 'http://www.meetup.com/members/191434382',
#   'lon': -0.1,
#   'name': 'Aarti Khatri',
#   'other_services': {},
#   'photo': {'base_url': 'https://secure.meetupstatic.com',
#             'highres_link': 'https://secure.meetupstatic.com/photos/member/4/d/b/5/highres_250519893.jpeg',
#             'photo_id': 250519893,
#             'photo_link': 'https://secure.meetupstatic.com/photos/member/4/d/b/5/member_250519893.jpeg',
#             'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/d/b/5/thumb_250519893.jpeg',
#             'type': 'member'},
#   'self': {'common': {}},
#   'state': '17',
#   'status': 'active',
#   'topics': [{'id': 408, 'name': 'Vegan', 'urlkey': 'vegan'},
#              {'id': 7203, 'name': 'Education & Technology', 'urlkey': 'edtech'},
#              {'id': 18296, 'name': 'Learning', 'urlkey': 'learning'},
#              {'id': 20629,
#               'name': 'Courses and Workshops',
#               'urlkey': 'courses-and-workshops'},
#              {'id': 8476, 'name': 'Education', 'urlkey': 'education'},
#              {'id': 30928,
#               'name': 'Data Analytics',
#               'urlkey': 'data-analytics'},
#              {'id': 18062, 'name': 'Big Data', 'urlkey': 'big-data'},
#              {'id': 10296, 'name': 'Women in Technology', 'urlkey': 'witi'},
#              {'id': 3833,
#               'name': 'Software Development',
#               'urlkey': 'softwaredev'},
#              {'id': 87548,
#               'name': 'Food and Drink',
#               'urlkey': 'food-and-drink'}],
#   'visited': 1463909552000},
#  {'city': 'Stratford ',
#   'country': 'gb',
#   'id': 206148213,
#   'joined': 1490794043000,
#   'lat': 51.54,
#   'link': 'http://www.meetup.com/members/206148213',
#   'lon': 0,
#   'name': 'Aashik Shah',
#   'other_services': {},
#   'photo': {'base_url': 'https://secure.meetupstatic.com',
#             'highres_link': 'https://secure.meetupstatic.com/photos/member/6/2/d/b/highres_257005307.jpeg',
#             'photo_id': 257005307,
#             'photo_link': 'https://secure.meetupstatic.com/photos/member/6/2/d/b/member_257005307.jpeg',
#             'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/2/d/b/thumb_257005307.jpeg',
#             'type': 'member'},
#   'self': {'common': {}},
#   'status': 'active',
#   'topics': [{'id': 108403,
#               'name': 'Technology Startups',
#               'urlkey': 'technology-startups'},
#              {'id': 3833,
#               'name': 'Software Development',
#               'urlkey': 'softwaredev'},
#              {'id': 18062, 'name': 'Big Data', 'urlkey': 'big-data'}],
#   'visited': 1491807312000},
#  {'bio': 'Scientist at the Medical Research Council',
#   'city': 'London',
#   'country': 'gb',
#   'id': 111017432,
#   'joined': 1379021156000,
#   'lat': 51.53,
#   'link': 'http://www.meetup.com/members/111017432',
#   'lon': -0.08,
#   'name': 'AB',
#   'other_services': {},
#   'photo': {'base_url': 'https://secure.meetupstatic.com',
#             'highres_link': 'https://secure.meetupstatic.com/photos/member/b/f/7/e/highres_146089022.jpeg',
#             'photo_id': 146089022,
#             'photo_link': 'https://secure.meetupstatic.com/photos/member/b/f/7/e/member_146089022.jpeg',
#             'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/f/7/e/thumb_146089022.jpeg',
#             'type': 'member'},
#   'self': {'common': {}},
#   'state': '17',
#   'status': 'active',
#   'topics': [{'id': 1566, 'name': 'Rock Climbing', 'urlkey': 'rockclimbing'},
#              {'id': 15892, 'name': 'Adventure', 'urlkey': 'adventure'},
#              {'id': 17703, 'name': 'London', 'urlkey': 'london'},
#              {'id': 18062, 'name': 'Big Data', 'urlkey': 'big-data'},
#              {'id': 39012, 'name': 'Arduino', 'urlkey': 'arduino'},
#              {'id': 43887, 'name': 'Makers', 'urlkey': 'makers'},
#              {'id': 55324, 'name': 'Data Mining', 'urlkey': 'data-mining'},
#              {'id': 102811, 'name': 'Data Science', 'urlkey': 'data-science'},
#              {'id': 108403,
#               'name': 'Technology Startups',
#               'urlkey': 'technology-startups'},
#              {'id': 1998, 'name': 'Travel', 'urlkey': 'travel'}],
#   'visited': 1395148346000}]
